# %%
# !pip install yfinance
# Out:
# ...
#   Using cached yfinance-0.1.74-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 1.1 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# simpletaxifare 1.0 requires scikit-learn==0.22, but you have scikit-learn 0.23.2 which is incompatible.
# simpletaxifare 1.0 requires six==1.15.0, but you have six 1.14.0 which is incompatible.
# taxifaremodel 1.0 requires scikit-learn==0.22, but you have scikit-learn 0.23.2 which is incompatible.
# ...

# %%
import yfinance as yf

# %%
tsla = yf.Ticker("AAPL")

# %%
tsla.calendar
# Out:
#                                     0                    1
# Earnings Date     2022-10-26 20:00:00  2022-10-31 20:00:00
# Earnings Average                 1.26                 1.26
# Earnings Low                     1.13                 1.13
# Earnings High                    1.35                 1.35
# Revenue Average           88721000000          88721000000
# Revenue Low               85144300000          85144300000
# Revenue High              92794900000          92794900000

# %%
tsla.get_balance_sheet()
# Out:
#                                                 2021-09-25    2020-09-26  \
# Total Liab                                    2.879120e+11  2.585490e+11
# Total Stockholder Equity                      6.309000e+10  6.533900e+10
# Other Current Liab                            5.357700e+10  4.786700e+10
# Total Assets                                  3.510020e+11  3.238880e+11
# Common Stock                                  5.736500e+10  5.077900e+10
# Other Current Assets                          1.411100e+10  1.126400e+10
# Retained Earnings                             5.562000e+09  1.496600e+10
# Other Liab                                    4.305000e+10  4.610800e+10
# Gains Losses Not Affecting Retained Earnings  1.630000e+08 -4.060000e+08
# Other Assets                                  3.876200e+10  3.395200e+10
# Cash                                          3.494000e+10  3.801600e+10
# Total Current Liabilities                     1.254810e+11  1.053920e+11
# ...

# %%
tsla.balance_sheet
# Out:
#                                                 2021-09-25    2020-09-26  \
# Total Liab                                    2.879120e+11  2.585490e+11
# Total Stockholder Equity                      6.309000e+10  6.533900e+10
# Other Current Liab                            5.357700e+10  4.786700e+10
# Total Assets                                  3.510020e+11  3.238880e+11
# Common Stock                                  5.736500e+10  5.077900e+10
# Other Current Assets                          1.411100e+10  1.126400e+10
# Retained Earnings                             5.562000e+09  1.496600e+10
# Other Liab                                    4.305000e+10  4.610800e+10
# Gains Losses Not Affecting Retained Earnings  1.630000e+08 -4.060000e+08
# Other Assets                                  3.876200e+10  3.395200e+10
# Cash                                          3.494000e+10  3.801600e+10
# Total Current Liabilities                     1.254810e+11  1.053920e+11
# ...

# %%
tsla.quarterly_balance_sheet
# Out:
#                                                 2022-06-25    2022-03-26  \
# Total Liab                                    2.782020e+11  2.832630e+11
# Total Stockholder Equity                      5.810700e+10  6.739900e+10
# Other Current Liab                            5.653900e+10  5.816800e+10
# Total Assets                                  3.363090e+11  3.506620e+11
# Common Stock                                  6.211500e+10  6.118100e+10
# Other Current Assets                          1.638600e+10  1.580900e+10
# Retained Earnings                             5.289000e+09  1.271200e+10
# Other Liab                                    5.362900e+10  5.243200e+10
# Gains Losses Not Affecting Retained Earnings -9.297000e+09 -6.494000e+09
# Other Assets                                  5.260500e+10  5.195900e+10
# Cash                                          2.750200e+10  2.809800e+10
# Total Current Liabilities                     1.298730e+11  1.275080e+11
# ...

# %%
tsla.quarterly_balance_sheet.keys()
# Out:
# DatetimeIndex(['2022-06-25', '2022-03-26', '2021-12-25', '2021-09-25'], dtype='datetime64[ns]', name='', freq=None)

# %%
tsla.quarterly_balance_sheet['2022-06-25'].info
# Out:
# <bound method Series.info of Total Liab                                      2.782020e+11
# Total Stockholder Equity                        5.810700e+10
# Other Current Liab                              5.653900e+10
# Total Assets                                    3.363090e+11
# Common Stock                                    6.211500e+10
# Other Current Assets                            1.638600e+10
# Retained Earnings                               5.289000e+09
# Other Liab                                      5.362900e+10
# Gains Losses Not Affecting Retained Earnings   -9.297000e+09
# Other Assets                                    5.260500e+10
# Cash                                            2.750200e+10
# Total Current Liabilities                       1.298730e+11
# Short Long Term Debt                            1.400900e+10
# Other Stockholder Equity                       -9.297000e+09
# Property Plant Equipment                        4.033500e+10
# ...

# %%
tsla.quarterly_balance_sheet
# Out:
#                                                 2022-06-25    2022-03-26  \
# Total Liab                                    2.782020e+11  2.832630e+11
# Total Stockholder Equity                      5.810700e+10  6.739900e+10
# Other Current Liab                            5.653900e+10  5.816800e+10
# Total Assets                                  3.363090e+11  3.506620e+11
# Common Stock                                  6.211500e+10  6.118100e+10
# Other Current Assets                          1.638600e+10  1.580900e+10
# Retained Earnings                             5.289000e+09  1.271200e+10
# Other Liab                                    5.362900e+10  5.243200e+10
# Gains Losses Not Affecting Retained Earnings -9.297000e+09 -6.494000e+09
# Other Assets                                  5.260500e+10  5.195900e+10
# Cash                                          2.750200e+10  2.809800e+10
# Total Current Liabilities                     1.298730e+11  1.275080e+11
# ...

# %%
tsla.quarterly_balance_sheet['2022-06-25']
# Out:
# Total Liab                                      2.782020e+11
# Total Stockholder Equity                        5.810700e+10
# Other Current Liab                              5.653900e+10
# Total Assets                                    3.363090e+11
# Common Stock                                    6.211500e+10
# Other Current Assets                            1.638600e+10
# Retained Earnings                               5.289000e+09
# Other Liab                                      5.362900e+10
# Gains Losses Not Affecting Retained Earnings   -9.297000e+09
# Other Assets                                    5.260500e+10
# Cash                                            2.750200e+10
# Total Current Liabilities                       1.298730e+11
# Short Long Term Debt                            1.400900e+10
# Other Stockholder Equity                       -9.297000e+09
# Property Plant Equipment                        4.033500e+10
# ...

# %%
tsla.quarterly_cashflow['2022-06-25']
# Out:
# Investments                                  6.953000e+09
# Change To Liabilities                       -4.725000e+09
# Total Cashflows From Investing Activities    4.234000e+09
# Net Borrowings                               9.710000e+08
# Total Cash From Financing Activities        -2.744500e+10
# Change To Operating Activities               2.497000e+09
# Net Income                                   1.944200e+10
# Change In Cash                              -3.190000e+08
# Repurchase Of Stock                         -2.456200e+10
# Total Cash From Operating Activities         2.289200e+10
# Depreciation                                 2.805000e+09
# Other Cashflows From Investing Activities   -6.150000e+08
# Dividends Paid                              -3.811000e+09
# Change To Inventory                         -1.600000e+07
# Change To Account Receivables               -9.810000e+08
# Other Cashflows From Financing Activities   -4.300000e+07
# ...

# %%
tsla.quarterly_financials['2022-06-25']
# Out:
# Research Development                       6797000000.0
# Effect Of Accounting Charges                       None
# Income Before Tax                         23066000000.0
# Minority Interest                                  None
# Net Income                                19442000000.0
# Selling General Administrative             6012000000.0
# Gross Profit                              35885000000.0
# Ebit                                      23076000000.0
# Operating Income                          23076000000.0
# Other Operating Expenses                           None
# Interest Expense                           -719000000.0
# Extraordinary Items                                None
# Non Recurring                                      None
# Other Items                                        None
# Income Tax Expense                         3624000000.0
# Total Revenue                             82959000000.0
# Total Operating Expenses                  59883000000.0
# ...

# %%
tsla.info.keys()
# Out:
# dict_keys(['zip', 'sector', 'fullTimeEmployees', 'longBusinessSummary', 'city', 'phone', 'state', 'country', 'companyOfficers', 'website', 'maxAge', 'address1', 'industry', 'ebitdaMargins', 'profitMargins', 'grossMargins', 'operatingCashflow', 'revenueGrowth', 'operatingMargins', 'ebitda', 'targetLowPrice', 'recommendationKey', 'grossProfits', 'freeCashflow', 'targetMedianPrice', 'currentPrice', 'earningsGrowth', 'currentRatio', 'returnOnAssets', 'numberOfAnalystOpinions', 'targetMeanPrice', 'debtToEquity', 'returnOnEquity', 'targetHighPrice', 'totalCash', 'totalDebt', 'totalRevenue', 'totalCashPerShare', 'financialCurrency', 'revenuePerShare', 'quickRatio', 'recommendationMean', 'exchange', 'shortName', 'longName', 'exchangeTimezoneName', 'exchangeTimezoneShortName', 'isEsgPopulated', 'gmtOffSetMilliseconds', 'quoteType', 'symbol', 'messageBoardId', 'market', 'annualHoldingsTurnover', 'enterpriseToRevenue', 'beta3Year', 'enterpriseToEbitda', '52WeekChange', 'morningStarRiskRating', 
# ...

# %%
tsla.quarterly_cashflow['2022-06-25']
# Out:
# Investments                                  6.953000e+09
# Change To Liabilities                       -4.725000e+09
# Total Cashflows From Investing Activities    4.234000e+09
# Net Borrowings                               9.710000e+08
# Total Cash From Financing Activities        -2.744500e+10
# Change To Operating Activities               2.497000e+09
# Net Income                                   1.944200e+10
# Change In Cash                              -3.190000e+08
# Repurchase Of Stock                         -2.456200e+10
# Total Cash From Operating Activities         2.289200e+10
# Depreciation                                 2.805000e+09
# Other Cashflows From Investing Activities   -6.150000e+08
# Dividends Paid                              -3.811000e+09
# Change To Inventory                         -1.600000e+07
# Change To Account Receivables               -9.810000e+08
# Other Cashflows From Financing Activities   -4.300000e+07
# ...

# %%
type(tsla.quarterly_cashflow['2022-06-25']["Issuance Of Stock"])

# %%
print(tsla.ticker)
# Out:
# AAPL

# %%
symbol = 'AAPL'

# %%
az = yf.Ticker(str(symbol))

# %%
print(az)
# Out:
# yfinance.Ticker object <AAPL>

# %%
az.quarterly_financials.T
# Out:
#            Research Development Effect Of Accounting Charges  \
#
# 2022-06-25         6797000000.0                         None
# 2022-03-26         6387000000.0                         None
# 2021-12-25         6306000000.0                         None
# 2021-09-25         5772000000.0                         None
#
#            Income Before Tax Minority Interest     Net Income  \
#
# 2022-06-25     23066000000.0              None  19442000000.0
# 2022-03-26     30139000000.0              None  25010000000.0
# 2021-12-25     41241000000.0              None  34630000000.0
# 2021-09-25     23248000000.0              None  20551000000.0
#
#            Selling General Administrative   Gross Profit           Ebit  \
#
# 2022-06-25                   6012000000.0  35885000000.0  23076000000.0
# 2022-03-26                   6193000000.0  42559000000.0  29979000000.0
# 2021-12-25                   6449000000.0  54243000000.0  41488000000.0
# ...

# %%
tsla.quarterly_cashflow.T.keys()
# Out:
# Index(['Investments', 'Change To Liabilities',
#        'Total Cashflows From Investing Activities', 'Net Borrowings',
#        'Total Cash From Financing Activities',
#        'Change To Operating Activities', 'Net Income', 'Change In Cash',
#        'Repurchase Of Stock', 'Total Cash From Operating Activities',
#        'Depreciation', 'Other Cashflows From Investing Activities',
#        'Dividends Paid', 'Change To Inventory',
#        'Change To Account Receivables',
#        'Other Cashflows From Financing Activities', 'Change To Netincome',
#        'Capital Expenditures', 'Issuance Of Stock'],
#       dtype='object')

# %%
type(tsla.quarterly_cashflow.T['Issuance Of Stock'][0])
# Out:
# numpy.float64

# %%
tsla.quarterly_cashflow[tsla.quarterly_cashflow.to_pydatetime() == datetime.datetime(2022,6,25)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bn/3hn0vc_12j3_6mz39fsz1xwh0000gn/T/ipykernel_7070/396655468.py in <module>
# ----> 1 tsla.quarterly_cashflow[tsla.quarterly_cashflow.to_pydatetime() == datetime.datetime(2022,6,25)]
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_pydatetime'
